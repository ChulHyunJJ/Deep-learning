# %% [markdown]
# ## 다항 회귀 (Nonlinear Regression)

# %% [markdown]
# ### modules import

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
plt.style.use(['seaborn-white'])

# %%
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# ### Hyper Parameters

# %%
epochs = 1000
learning_rate = 0.04

# %% [markdown]
# ### 변수 지정

# %%
a = tf.Variable(np.random.randn())
b = tf.Variable(np.random.randn())
c = tf.Variable(np.random.randn())
d = tf.Variable(np.random.randn())

# %%
print(a.numpy())
print(b.numpy())
print(c.numpy())
print(d.numpy())
# Out:
# 1.9152769
# -0.9846015
# 0.42523497
# 1.285182

# %% [markdown]
# ### 데이터 지정

# %%
X = np.random.randn(50)
Y = X**2 + X*np.random.randn(50)

# %%
line_x = np.arange(min(X), max(X), 0.001)
line_y = a * line_x**3 + b*line_x**2 + c*line_x + d

x_ = np.arange(-4.0, 4.0, 0.001)
y_ = a * x_**3 + b*x_**2 + c*x_ + d

plt.scatter(X, Y, label='X data')
plt.plot(x_, y_, 'g--', label='origin line')
plt.plot(line_x, line_y, 'r--', label='before train')
plt.xlim(-4.0, 4.0)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### Util Functions

# %%
def computer_loss():
  pred_y = a * (np.array(X) ** 3) + b* (np.array(X) **2) + c * (np.array(X)) + d
  loss = tf.reduce_mean((Y - pred_y) ** 2)
  return loss

# %% [markdown]
# ### Optimizer

# %%
optimizer = Adam(learning_rate = learning_rate)

# %% [markdown]
# ### 학습

# %%
for epoch in range(1, epochs+1, 1):
  optimizer.minimize(computer_loss, var_list=[a, b, c, d])

  if epoch % 100 == 0:
    print('epoch: {:4d}\ta: {:.4f}\tb: {:.4f}\tc: {:.4f}\td: {:.4f}'.format(epoch, a.numpy(), b.numpy(), c.numpy(), d.numpy()))
# Out:
# epoch:  100	a: 0.1609	b: 1.1101	c: -0.8884	d: 0.0008
# epoch:  200	a: 0.0790	b: 1.2073	c: -0.4051	d: -0.1739
# epoch:  300	a: 0.0038	b: 1.1430	c: -0.1235	d: -0.1206
# epoch:  400	a: -0.0373	b: 1.1072	c: 0.0298	d: -0.0905
# epoch:  500	a: -0.0554	b: 1.0914	c: 0.0973	d: -0.0772
# epoch:  600	a: -0.0619	b: 1.0857	c: 0.1218	d: -0.0724
# epoch:  700	a: -0.0639	b: 1.0839	c: 0.1292	d: -0.0710
# epoch:  800	a: -0.0644	b: 1.0835	c: 0.1310	d: -0.0706
# epoch:  900	a: -0.0645	b: 1.0834	c: 0.1314	d: -0.0705
# epoch: 1000	a: -0.0645	b: 1.0834	c: 0.1315	d: -0.0705

# %% [markdown]
# ### 학습 후의 회귀선

# %%
line_x = np.arange(min(X), max(X), 0.001)
line_y = a * line_x**3 + b*line_x**2 + c*line_x + d

plt.scatter(X, Y, label='X data')
plt.plot(x_, y_, 'g--', label='origin line')
plt.plot(line_x, line_y, 'r--', label='before train')
plt.xlim(-4.0, 4.0)
plt.legend()
plt.grid()
plt.show()
